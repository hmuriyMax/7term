# %%
import matplotlib.pyplot as plt
import os

# %%
js

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.view_init(150, 120, 135)
ax.scatter(x, y, z, s=20, c=z, cmap='coolwarm')
